# %%
import json
import numpy as np
import pandas as pd

# def generate_df_json_cols(df):
#     for col in df.columns:
#         series = df[col].copy()
#         df_col = pd.DataFrame(series.tolist()).dropna(axis=0)
#         df_col = df_col.astype({'id': 'int64'})
#         df_col = df_col.set_index('id')
#         df_col.to_csv(col + '.csv')
#         df[col] = df[col].apply(lambda x: x['id'] if 'id' in x else -1)
#     return df

def generate_df_json_cols(df):
    for col in df.columns:
        df[col] = df[col].apply(lambda x: x['name'] if 'name' in x else np.nan)
    return df

def generate_df_json_arr_cols(df):
    # For simplicity, for now we only take the first element of the array.
    for col in df.columns:
        df[col] = df[col].apply(lambda x: x[0]['name'] if len(x) > 0 and 'name' in x[0] else np.nan)
    return df

if __name__ == "__main__":
    json_path = "../KafkaStreamProcess/ProcessedDataSample/MovieDataStore.json"

    json_features = ['belongs_to_collection']
    json_arr_features = ['genres', 'production_companies', 'production_countries', 'spoken_languages']
    useless_features = ['original_title', 'homepage', 'poster_path', 'status', 'tagline']

    with open(json_path) as json_file:
        data = json.load(json_file)

    list_of_dict = [json.loads(data[movie_name]) for movie_name in data]

    df = pd.DataFrame(list_of_dict)
    df.set_index('tmdb_id')

    # drop the useless_features
    df = df.drop(useless_features, axis=1)

    df_json = generate_df_json_cols(df[json_features].copy())
    df = df.drop(json_features, axis=1)

    df_json_arr = generate_df_json_arr_cols(df[json_arr_features].copy())
    df = df.drop(json_arr_features, axis=1)

    result = pd.concat([df, df_json, df_json_arr], axis=1)
    result.to_csv('movie_data_clean.csv')

# %%
result
# Out:
#       adult     budget                                                 id  \
# 0     False    2000000                                   melody+time+1948
# 1     False          0                                     diplomacy+2014
# 2     False          0                                        marley+2012
# 3     False          0                                    l.a.+story+1991
# 4     False          0                                 a+special+day+1977
# 5     False          0                                  the+sea+gull+1968
# 6     False    6000000                                   blue+velvet+1986
# 7     False          0                                a+better+place+1997
# 8     False          0                                 private+lives+1931
# 9     False   10000000                              imaginary+heroes+2004
# 10    False          0                            i+met+him+in+paris+1937
# 11    False    4000000                                    bad+dreams+1988
# 12    False          0                              a+beautiful+life+2008
# 13    False          0                                 queen+to+play+2009
# 14    False   25000000                                      the+hoax+2006
# 15    False          0                      caterina+in+the+big+city+2003
# 16    False          0                                    one+man+up+2001
# 17    False   19000000                                   the+goonies+1985
# 18    False          0                            blue+gate+crossing+2002
# 19    False          0                             one+hour+with+you+1932
# 20    False          0                                breathing+room+2008
# 21    False          0                                    under+fire+1983
# 22    False          0                    the+story+of+louis+pasteur+1936
# 23    False    6000000                                 the+protector+2005
# 24    False   32000000                                    the+master+2012
# 25    False          0                             middle+of+nowhere+2012
# 26    False          0                          another+harvest+moon+2010
# 27    False          0                                         gonin+1995
# 28    False          0                                    the+chosen+1981
# 29    False    5000000  shriek+if+you+know+what+i+did+last+friday+the+...
# ...     ...        ...                                                ...
# 1201  False          0                                     slap+shot+1977
# 1202  False          0                                     train+man+2005
# 1203  False   55000000                              any+given+sunday+1999
# 1204  False          0                               nobody+loves+me+1994
# 1205  False          0                                  bombay+beach+2011
# 1206  False          0                               stealing+beauty+1996
# 1207  False          0                                double+suicide+1969
# 1208  False   24000000                    zack+and+miri+make+a+porno+2008
# 1209  False          0                                         35+up+1991
# 1210  False   20000000                                      miserere+2013
# 1211  False          0                       the+ballad+of+little+jo+1993
# 1212  False          0                                 toto+the+hero+1991
# 1213  False    2068000                                      gaslight+1944
# 1214  False          0                                  sunes+sommar+1993
# 1215  False  100000000                                 war+and+peace+1966
# 1216  False          0                              a+pure+formality+1994
# 1217  False          0                               black+and+white+1968
# 1218  False          0                                    pentimento+1979
# 1219  False          0                     ivan+the+terrible_+part+i+1945
# 1220  False          0                           the+small+back+room+1949
# 1221  False    3352254                                   the+getaway+1972
# 1222  False          0                            step+up+love+story+2000
# 1223  False          0        to+get+to+heaven+first+you+have+to+die+2006
# 1224  False          0               the+adventures+of+milo+and+otis+1986
# 1225  False          0                                      no+mercy+2010
# 1226  False          0                             the+turning+point+1977
# 1227  False          0                                     bandwagon+1996
# 1228  False   39000000                             coming+to+america+1988
# 1229  False          0                                        loulou+1980
# 1230  False          0                                the+naked+spur+1953
#
#         imdb_id original_language  \
# 0     tt0040580                en
# 1     tt3129564                fr
# 2     tt1183919                en
# 3     tt0102250                en
# 4     tt0076085                it
# 5     tt0063569                en
# 6     tt0090756                en
# 7     tt0118705                en
# 8     tt0022279                en
# 9     tt0373024                en
# 10    tt0029036                en
# 11    tt0094701                en
# 12    tt1043787                en
# 13    tt1082009                fr
# 14    tt0462338                en
# 15    tt0366287                it
# 16    tt0295671                it
# 17    tt0089218                en
# 18    tt0333764                zh
# 19    tt0023303                en
# 20    tt1220706                en
# 21    tt0086510                en
# 22    tt0028313                en
# 23    tt0427954                th
# 24    tt1560747                en
# 25    tt1211890                en
# 26    tt1129404                en
# 27    tt0113194                ja
# 28    tt0082175                en
# 29    tt0212235                en
# ...         ...               ...
# 1201  tt0076723                en
# 1202  tt0456121                ja
# 1203  tt0146838                en
# 1204  tt0110251                de
# 1205  tt1758576                en
# 1206  tt0117737                en
# 1207  tt0064975                ja
# 1208  tt1007028                en
# 1209  tt0101254                en
# 1210  tt2354215                fr
# 1211  tt0106350                en
# 1212  tt0103105                fr
# 1213  tt0036855                en
# 1214  tt0108252                sv
# 1215  tt0063794                ru
# 1216  tt0110917                fr
# 1217  tt0062012                en
# 1218  tt0254676                en
# 1219  tt0037824                ru
# 1220  tt0041886                en
# 1221  tt0068638                en
# 1222  tt0929753                en
# 1223  tt0792988                tg
# 1224  tt0097050                ja
# 1225  tt1662557                ko
# 1226  tt0076843                en
# 1227  tt0112454                en
# 1228  tt0094898                en
# 1229  tt0081076                fr
# 1230  tt0044953                en
#
#                                                overview popularity  \
# 0     Melody Time is an animated feature produced by...   6.771815
# 1     The night of August 24, 1944. The fate of Pari...   3.848346
# 2     Bob Marley's universal appeal, impact on music...   5.825337
# 3     With the help of a talking freeway billboard, ...   7.775188
# 4     The film is set during the late 1930s: the occ...   3.810981
# 5     Film adaptation of Anton Chekhov's story of li...   0.529771
# 6     The discovery of a severed human ear found in ...   7.882247
# 7     A high school outcast new to town becomes frie...    0.33244
# 8     Elyot and Sibyl are being married in a big chu...   0.220294
# 9     Matt Travis is good-looking, popular, and his ...   2.994171
# 10    Kay Denham is off for a 'fling' in Paris, leav...   0.730017
# 11    Unity Field, a "free love" cult from the '70s,...   5.296777
# 12    A love story about the encounter of two drifti...   0.031905
# 13    In a small Corsican village, the life of Hélèn...    2.94798
# 14    In what would cause a fantastic media frenzy, ...    4.78586
# 15    When her father, Giancarlo is transferred to R...   3.162693
# 16    The debut feature by acclaimed Italian directo...   1.270431
# 17    A young teenager named Mikey Walsh finds an ol...  14.280703
# 18    An is-she-or-isn't-she gay comedy focused on a...   2.389238
# 19    Andre and Colette Bertier are happily married....   1.406699
# 20    Thrown naked into a desolate room with thirtee...   1.776816
# 21    Three U.S. journalists (Nick Nolte, Joanna Cas...   2.780331
# 22    In 1860, having helped France solve the proble...   0.762512
# 23    In Bangkok, the young Kham was raised by his f...   9.005167
# 24    Freddie, a volatile, heavy-drinking veteran wh...   8.074218
# 25    'Middle of Nowhere' follows a woman named Ruby...    1.50978
# 26    Another Harvest Moon is a tender drama about f...   0.132857
# 27    Five men plot to steal a large sum of money fr...    1.51489
# 28    The Chosen follows the story of two teenage bo...   0.888234
# 29    Another spoof of the Scream/I Know What You Di...   3.956594
# ...                                                 ...        ...
# 1201  Located in the US Rust Belt, Charlestown is ho...   9.282077
# 1202  Densha Otoko (translated as Train Man) is a Ja...   0.703244
# 1203  A star quarterback gets knocked out of the gam...  10.571434
# 1204                                 No overview found.   1.015068
# 1205  Bombay Beach is one of the poorest communities...   0.274196
# 1206  Lucy Harmon, an American teenager is arriving ...   6.418805
# 1207  Set in Osaka in the 18th century, the film cen...   1.160174
# 1208  Lifelong platonic friends Zack and Miri look t...   6.449332
# 1209  Director Michael Apted revisits the same group...   0.930397
# 1210  Paris, December. A conductor of a choir is fou...   2.237861
# 1211  Based on a true story, this is the tale of Jos...   1.049852
# 1212  Thomas and Alfred were born around the same ti...   2.582899
# 1213  In the late 19th century, Paula Alquist is stu...  14.545058
# 1214                                                      0.943978
# 1215  Seven-hour epic based on the eponymous book by...   2.604571
# 1216  Onoff (Depardieu,) is a famous writer, now a r...   4.619677
# 1217  Juha is a sales manager of a refrigerator comp...   0.101017
# 1218  This film is dominated by an icy blue. In a mo...   0.195532
# 1219  Sergei Eisenstein's final film, this is the fi...   2.121177
# 1220  At the height of World War II, the Germans beg...   0.751207
# 1221  A recently released ex-con and his loyal wife ...  10.037593
# 1222  Makoto and Yura Onoda are happy newlyweds but ...   0.318238
# 1223  Twenty-year-old Kamal has been married for a f...   0.166991
# 1224  The story of two animals and their adventures....   2.500605
# 1225  Forensic pathologist Kang (Seol Kyeong-gu) is ...   2.636798
# 1226  When her daughter joins a ballet company, a fo...   1.118538
# 1227  Tony gets fired from his job. He's not really ...   0.071847
# 1228  Prince Akeem, heir to the throne of Zamunda, l...   7.830087
# 1229  This 1980 French film features Isabelle Hupper...   1.982488
# 1230  Stewart is a bounty hunter in Colorado territo...   3.184967
#
#      release_date    revenue  runtime  \
# 0      1948-05-27          0       72
# 1      2014-03-05    3946880       84
# 2      2012-04-20          0      144
# 3      1991-02-08          0       95
# 4      1977-08-11        110      110
# 5      1968-12-23          0      144
# 6      1986-08-01    8551228      120
# 7      1997-09-01          0       87
# 8      1931-12-12          0       84
# 9      2004-09-14          0      111
# 10     1937-05-28          0       86
# 11     1988-04-08    9797098       86
# 12     2008-08-14          0       81
# 13     2009-08-05    1056938       97
# 14     2006-10-14   11772461      116
# 15     2003-10-24          0      105
# 16     2001-08-31          0      100
# 17     1985-06-06   61503218      114
# 18     2002-09-27          0       85
# 19     1932-03-22          0       80
# 20     2008-08-25          0       89
# 21     1983-10-21          0      128
# 22     1936-02-22          0       86
# 23     2005-08-11   27165581      108
# 24     2012-09-07   28258060      137
# 25     2012-10-12          0      101
# 26     2010-10-06          0       89
# 27     1995-09-23          0      109
# 28     1981-08-20          0      105
# 29     2000-10-17          0       86
# ...           ...        ...      ...
# 1201   1977-02-25   28000000      123
# 1202   2005-06-04          0      105
# 1203   1999-12-16  100230832      163
# 1204   1994-11-07          0      104
# 1205   2011-10-14          0       80
# 1206   1996-03-29          0      116
# 1207   1969-05-24          0      104
# 1208   2008-09-18   42105111      102
# 1209   1991-08-29          0      123
# 1210   2013-06-26          0      106
# 1211   1993-08-20          0      121
# 1212   1991-05-15          0       91
# 1213   1944-05-04          0      114
# 1214   1993-12-25          0       83
# 1215   1966-03-14          0      422
# 1216   1994-05-15          0      108
# 1217   1968-03-15          0       95
# 1218   1979-02-01          0       78
# 1219   1945-04-23          0      103
# 1220   1949-02-21          0      106
# 1221   1972-12-13   58831997      118
# 1222   2000-01-01          0      120
# 1223   2006-10-04          0       95
# 1224   1986-06-27          0       90
# 1225   2010-01-07          0      125
# 1226   1977-11-14          0      119
# 1227   1996-01-08          0      103
# 1228   1988-06-28  288752301      116
# 1229   1980-09-03          0      101
# 1230   1953-02-06          0       91
#
#                                                   title  tmdb_id vote_average  \
# 0                                           Melody Time    13757          6.3
# 1                                             Diplomacy   253239          7.2
# 2                                                Marley    90125          7.5
# 3                                            L.A. Story     2107          6.4
# 4                                         A Special Day    42229          7.7
# 5                                          The Sea Gull   184795          8.5
# 6                                           Blue Velvet      793          7.7
# 7                                        A Better Place   107499          9.0
# 8                                         Private Lives    99283          6.1
# 9                                      Imaginary Heroes    25350          6.3
# 10                                   I Met Him in Paris   132506          5.5
# 11                                           Bad Dreams    59797          5.3
# 12                                     A Beautiful Life    58197          0.0
# 13                                        Queen to Play    42973          6.5
# 14                                             The Hoax     9903          6.4
# 15                             Caterina in the Big City    18503          6.5
# 16                                           One Man Up    53482          7.2
# 17                                          The Goonies     9340          7.4
# 18                                   Blue Gate Crossing    44708          7.2
# 19                                    One Hour with You    43145          5.4
# 20                                       Breathing Room    16179          4.1
# 21                                           Under Fire    12503          6.9
# 22                           The Story of Louis Pasteur    74469          6.6
# 23                                        The Protector     8982          6.8
# 24                                           The Master    68722          7.0
# 25                                    Middle of Nowhere    83588          6.6
# 26                                 Another Harvest Moon   134472          6.0
# 27                                                Gonin    26830          7.2
# 28                                           The Chosen    25773          7.3
# 29    Shriek If You Know What I Did Last Friday the ...     4226          4.8
# ...                                                 ...      ...          ...
# 1201                                          Slap Shot    11590          7.1
# 1202                                          Train Man    13299          6.5
# 1203                                   Any Given Sunday     9563          6.8
# 1204                                    Nobody Loves Me    11907          5.1
# 1205                                       Bombay Beach    83732          6.5
# 1206                                    Stealing Beauty    14553          6.6
# 1207                                     Double Suicide    45713          6.5
# 1208                         Zack and Miri Make a Porno    10358          6.1
# 1209                                              35 Up    20562          7.7
# 1210                                           Miserere   201759          6.2
# 1211                            The Ballad of Little Jo    71940          5.9
# 1212                                      Toto the Hero    56321          6.9
# 1213                                           Gaslight    13528          7.2
# 1214                                       Sunes sommar    30149          5.9
# 1215                                      War and Peace    29266          7.5
# 1216                                   A Pure Formality    19223          7.7
# 1217                                    Black and White   257716          3.5
# 1218                                         Pentimento   152943          7.4
# 1219                          Ivan the Terrible, Part I     9797          7.0
# 1220                                The Small Back Room    46096          6.6
# 1221                                        The Getaway     5916          7.0
# 1222                                 Step Up Love Story   288037          2.0
# 1223             To Get to Heaven First You Have to Die   120393          6.3
# 1224                    The Adventures of Milo and Otis    47951          6.7
# 1225                                           No Mercy    50475          7.6
# 1226                                  The Turning Point    61280          6.0
# 1227                                          Bandwagon    52472          7.5
# 1228                                  Coming to America     9602          6.5
# 1229                                             Loulou    39415          6.3
# 1230                                     The Naked Spur    20442          6.6
#
#      vote_count         belongs_to_collection       genres  \
# 0            42                           NaN        Music
# 1            73                           NaN        Drama
# 2           107                           NaN  Documentary
# 3            88                           NaN       Comedy
# 4            79                           NaN        Drama
# 5             2                           NaN      Romance
# 6           758                           NaN        Crime
# 7             1                           NaN        Drama
# 8             6                           NaN       Comedy
# 9            29                           NaN       Comedy
# 10            2                           NaN       Comedy
# 11           31                           NaN       Horror
# 12            0                           NaN        Drama
# 13           16                           NaN       Comedy
# 14           60                           NaN       Comedy
# 15           55                           NaN       Comedy
# 16           35                           NaN       Comedy
# 17         1563                           NaN    Adventure
# 18           19                           NaN        Drama
# 19            8                           NaN       Comedy
# 20           28                           NaN       Horror
# 21           38                           NaN          War
# 22            5                           NaN      History
# 23          171      The Protector Collection       Action
# 24          720                           NaN        Drama
# 25            7                           NaN        Drama
# 26            1                           NaN        Drama
# 27            6                           NaN       Action
# 28            6                           NaN        Drama
# 29           70                           NaN       Comedy
# ...         ...                           ...          ...
# 1201        102          Slap Shot Collection        Drama
# 1202         10                           NaN       Comedy
# 1203        430                           NaN        Drama
# 1204          5                           NaN        Drama
# 1205          7                           NaN  Documentary
# 1206         99                           NaN        Drama
# 1207         14                           NaN        Drama
# 1208        734                           NaN       Comedy
# 1209          8                           NaN  Documentary
# 1210         20                           NaN     Thriller
# 1211          5                           NaN      Romance
# 1212         24                           NaN        Drama
# 1213         73                           NaN        Drama
# 1214         17                           NaN       Comedy
# 1215         16                           NaN          War
# 1216         59                           NaN        Crime
# 1217          2                           NaN          NaN
# 1218          5                           NaN          NaN
# 1219         30  Ivan The Terrible Collection        Drama
# 1220         10                           NaN          War
# 1221        120                           NaN       Action
# 1222          1                           NaN    Animation
# 1223          3                           NaN        Drama
# 1224         54                           NaN    Adventure
# 1225         33                           NaN     Thriller
# 1226         16                           NaN        Drama
# 1227          2                           NaN       Comedy
# 1228        944                           NaN       Comedy
# 1229          9                           NaN        Drama
# 1230         45                           NaN       Action
#
#                          production_companies      production_countries  \
# 0                          RKO Radio Pictures  United States of America
# 1                                     Gaumont                    France
# 2                    Shangri-La Entertainment            United Kingdom
# 3                            TriStar Pictures  United States of America
# 4          Compagnia Cinematografica Champion                    Canada
# 5                  Warner Brothers/Seven Arts            United Kingdom
# 6     De Laurentiis Entertainment Group (DEG)  United States of America
# 7                      View Askew Productions  United States of America
# 8                   Metro-Goldwyn-Mayer (MGM)  United States of America
# 9                          Signature Pictures                   Belgium
# 10                         Paramount Pictures  United States of America
# 11                  No Frills Film Production  United States of America
# 12                                        NaN  United States of America
# 13                     Mon Voisin Productions                    France
# 14                              Miramax Films  United States of America
# 15                            Pretty Pictures                     Italy
# 16                                        NaN                     Italy
# 17                       Amblin Entertainment  United States of America
# 18                                        NaN                    Taiwan
# 19                         Paramount Pictures  United States of America
# 20                               BIG Pictures  United States of America
# 21                             Orion Pictures  United States of America
# 22                 First National Productions  United States of America
# 23                      The Weinstein Company                  Thailand
# 24                     Ghoulardi Film Company  United States of America
# 25                                        NaN  United States of America
# 26                                        NaN                       NaN
# 27                                        NaN                     Japan
# 28                        Chosen Film Company  United States of America
# 29                      Endless Entertainment  United States of America
# ...                                       ...                       ...
# 1201                       Universal Pictures  United States of America
# 1202                                      NaN                     Japan
# 1203                         Donners' Company  United States of America
# 1204                                      NaN                   Germany
# 1205                                      NaN  United States of America
# 1206                 Fox Searchlight Pictures                    France
# 1207                        Art Theatre Guild                     Japan
# 1208                               Blue Askew  United States of America
# 1209                                      NaN            United Kingdom
# 1210                    TF1 Films Productions                    France
# 1211                       Fine Line Features  United States of America
# 1212                              Iblis Films                   Belgium
# 1213                Metro-Goldwyn-Mayer (MGM)  United States of America
# 1214                                      NaN                       NaN
# 1215                                  Mosfilm                    Russia
# 1216                                  Sidonie                    France
# 1217                                      NaN                   Finland
# 1218                                      NaN                       NaN
# 1219                                  Mosfilm                    Russia
# 1220                  London Film Productions            United Kingdom
# 1221                        Solar Productions  United States of America
# 1222                                      NaN                     Japan
# 1223                   Pandora Filmproduktion                Tajikistan
# 1224                  Fuji Television Network                     Japan
# 1225                           Cinema Service               South Korea
# 1226   Twentieth Century Fox Film Corporation  United States of America
# 1227                  Lakeshore Entertainment  United States of America
# 1228                       Paramount Pictures  United States of America
# 1229                                  Gaumont                    France
# 1230                Metro-Goldwyn-Mayer (MGM)  United States of America
#
#      spoken_languages
# 0             English
# 1             Deutsch
# 2             English
# 3             English
# 4            Italiano
# 5             English
# 6             English
# 7                 NaN
# 8             English
# 9             English
# 10            English
# 11            English
# 12            English
# 13            English
# 14            English
# 15           Italiano
# 16           Italiano
# 17            English
# 18                普通话
# 19            English
# 20            English
# 21            English
# 22            English
# 23            English
# 24            English
# 25            English
# 26            English
# 27                日本語
# 28            English
# 29            English
# ...               ...
# 1201          English
# 1202              日本語
# 1203          English
# 1204          Deutsch
# 1205          English
# 1206          English
# 1207              日本語
# 1208          English
# 1209          English
# 1210         Français
# 1211              NaN
# 1212         Français
# 1213          English
# 1214          svenska
# 1215         Français
# 1216         Français
# 1217            suomi
# 1218              NaN
# 1219          Pусский
# 1220          English
# 1221          English
# 1222              NaN
# 1223          Pусский
# 1224              日本語
# 1225          한국어/조선말
# 1226          English
# 1227          English
# 1228          English
# 1229         Français
# 1230          English
#
# [1231 rows x 19 columns]
